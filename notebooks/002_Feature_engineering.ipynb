# %%
# %cd '../ds-ml-challenge-szafranskifilip'
# Out:
# /Users/filipszafranski/Desktop/repositories/ds-ml-challenge-szafranskifilip
# /Users/filipszafranski/Library/Python/3.11/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd
from datetime import datetime
import os

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_openai import ChatOpenAI

# %% [markdown]
# ### Load Data

# %%
df_github = pd.read_csv('data/github_repos_data.csv')
df_github
# Out:
#                                       name  \
# 0                                langchain
# 1                         ChatGPT-Next-Web
# 2                 awesome-machine-learning
# 3                              awesome-cpp
# 4                                llama.cpp
# ..                                     ...
# 512                awesome-transformer-nlp
# 513           awesome_LLMs_interview_notes
# 514                          chameleon-llm
# 515  bramses-highly-opinionated-vault-2023
# 516               offensive-ai-compilation
#
#                                          full_name  \
# 0                           langchain-ai/langchain
# 1                  ChatGPTNextWeb/ChatGPT-Next-Web
# 2            josephmisiti/awesome-machine-learning
# 3                              fffaraz/awesome-cpp
# 4                              ggerganov/llama.cpp
# ..                                             ...
# 512            cedrickchee/awesome-transformer-nlp
# 513         jackaduma/awesome_LLMs_interview_notes
# 514                        lupantech/chameleon-llm
# 515  bramses/bramses-highly-opinionated-vault-2023
# 516                  jiep/offensive-ai-compilation
#
#                                                 topics  \
# 0                                             no topic
# 1    chatgpt, cross-platform, desktop, fe, gemini, ...
# 2                                             no topic
# 3    awesome, awesome-list, c, c-plus-plus, cpp, cp...
# 4                                          ggml, llama
# ..                                                 ...
# 512  attention-mechanism, awesome, awesome-list, be...
# 513  ai, interview-practice, interview-preparation,...
# 514      ai, chatgpt, gpt-4, llm, openai, python, tool
# 515                                        obsidian-md
# 516  adversarial-machine-learning, ai-security, art...
#
#                                            description  created_at  \
# 0        🦜🔗 Build context-aware reasoning applications  2022-10-17
# 1    A cross-platform ChatGPT/Gemini UI (Web / PWA ...  2023-03-10
# 2    A curated list of awesome Machine Learning fra...  2014-07-15
# 3    A curated list of awesome C++ (or C) framework...  2014-07-17
# 4                               LLM inference in C/C++  2023-03-10
# ..                                                 ...         ...
# 512  A curated list of NLP resources focused on Tra...  2019-01-13
# 513  LLMs interview notes and answers:该仓库主要记录大模型（LL...  2023-09-21
# 514  Codes for "Chameleon: Plug-and-Play Compositio...  2023-04-19
# 515  A highly opinionated, fully featured Obsidian ...  2022-12-08
# 516  A curated list of useful resources that cover ...  2023-01-28
#
#      updated_at  stargazers_count  forks_count  \
# 0    2024-04-07             81425        12434
# 1    2024-04-07             66548        54259
# 2    2024-04-07             63304        14447
# 3    2024-04-07             55101         7613
# 4    2024-04-07             54581         7703
# ..          ...               ...          ...
# 512  2024-04-01              1022          122
# 513  2024-04-07              1019          161
# 514  2024-04-02              1009           84
# 515  2024-04-03              1009           49
# 516  2024-04-07              1002           98
#
#                                                license
# 0                                          MIT License
# 1                                          MIT License
# 2                                                Other
# 3                                          MIT License
# 4                                          MIT License
# ..                                                 ...
# 512                                        MIT License
# 513                                        MIT License
# 514                                 Apache License 2.0
# 515                                        MIT License
# 516  Creative Commons Attribution Share Alike 4.0 I...
#
# [517 rows x 9 columns]

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# 1. Create a column 'days_since_created' which states the age of a repository

# %%
# Convert 'created_at' column to datetime
df_github['created_at'] = pd.to_datetime(df_github['created_at'])

# Calculate the number of days from 'created_at' to today
# Note: datetime.now() gives the current date and time; datetime.today() gives the current date with the time set to midnight.
df_github['days_since_created'] = (datetime.now() - df_github['created_at']).dt.days

# %% [markdown]
# 2. Create a column 'forks/day' which states the ratio of forks_count and days_since_created

# %%
df_github['avg_forks_per_day'] = round(df_github['forks_count']/df_github['days_since_created'], 0)
df_github['avg_stars_per_day'] = round(df_github['stargazers_count']/df_github['days_since_created'], 0)
df_github.drop(columns=['updated_at'], inplace=True)
df_github.head()
# Out:
#                        name                              full_name  \
# 0                 langchain                 langchain-ai/langchain
# 1          ChatGPT-Next-Web        ChatGPTNextWeb/ChatGPT-Next-Web
# 2  awesome-machine-learning  josephmisiti/awesome-machine-learning
# 3               awesome-cpp                    fffaraz/awesome-cpp
# 4                 llama.cpp                    ggerganov/llama.cpp
#
#                                               topics  \
# 0                                           no topic
# 1  chatgpt, cross-platform, desktop, fe, gemini, ...
# 2                                           no topic
# 3  awesome, awesome-list, c, c-plus-plus, cpp, cp...
# 4                                        ggml, llama
#
#                                          description created_at  \
# 0      🦜🔗 Build context-aware reasoning applications 2022-10-17
# 1  A cross-platform ChatGPT/Gemini UI (Web / PWA ... 2023-03-10
# 2  A curated list of awesome Machine Learning fra... 2014-07-15
# 3  A curated list of awesome C++ (or C) framework... 2014-07-17
# 4                             LLM inference in C/C++ 2023-03-10
#
#    stargazers_count  forks_count      license  days_since_created  \
# 0             81425        12434  MIT License                 540
# 1             66548        54259  MIT License                 396
# 2             63304        14447        Other                3556
# 3             55101         7613  MIT License                3554
# 4             54581         7703  MIT License                 396
#
#    avg_forks_per_day  avg_stars_per_day
# 0               23.0              151.0
# 1              137.0              168.0
# 2                4.0               18.0
# 3                2.0               16.0
# 4               19.0              138.0

# %% [markdown]
# 3. Use llm (OpenaAI) and Langchain to assign categories to each repository (Tagging)

# %%
# Load OpeanAI api key form the environment variables
OPENAI_API_KEY = os.environ.get('OPENAI_API_KEY')

def assign_category(inp: str) -> str:

    if inp is None or pd.isna(inp):
        return "Unknown"
    
    tagging_prompt = ChatPromptTemplate.from_template(
        """
    Extract the desired information from the following passage.

    Only extract the properties mentioned in the 'Classification' function.

    Passage:
    {input}
    """
    )

    class Classification(BaseModel):
        category: str = Field(description="The category of the text.", 
                              enum=['Tutorials', 'Applications', 'AI engineering', 'Model development', 'Model repo', 'Infrastructure', 'Lists'])


    # LLM
    llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0125").with_structured_output(
        Classification
    )

    tagging_chain = tagging_prompt | llm
    results = tagging_chain.invoke({"input": inp})
    return results.category

# %%
df_github['categories'] = df_github['description'].apply(assign_category)

# %%
df_github
# Out:
#                                       name  \
# 0                                langchain
# 1                         ChatGPT-Next-Web
# 2                 awesome-machine-learning
# 3                              awesome-cpp
# 4                                llama.cpp
# ..                                     ...
# 512                awesome-transformer-nlp
# 513           awesome_LLMs_interview_notes
# 514                          chameleon-llm
# 515  bramses-highly-opinionated-vault-2023
# 516               offensive-ai-compilation
#
#                                          full_name  \
# 0                           langchain-ai/langchain
# 1                  ChatGPTNextWeb/ChatGPT-Next-Web
# 2            josephmisiti/awesome-machine-learning
# 3                              fffaraz/awesome-cpp
# 4                              ggerganov/llama.cpp
# ..                                             ...
# 512            cedrickchee/awesome-transformer-nlp
# 513         jackaduma/awesome_LLMs_interview_notes
# 514                        lupantech/chameleon-llm
# 515  bramses/bramses-highly-opinionated-vault-2023
# 516                  jiep/offensive-ai-compilation
#
#                                                 topics  \
# 0                                             no topic
# 1    chatgpt, cross-platform, desktop, fe, gemini, ...
# 2                                             no topic
# 3    awesome, awesome-list, c, c-plus-plus, cpp, cp...
# 4                                          ggml, llama
# ..                                                 ...
# 512  attention-mechanism, awesome, awesome-list, be...
# 513  ai, interview-practice, interview-preparation,...
# 514      ai, chatgpt, gpt-4, llm, openai, python, tool
# 515                                        obsidian-md
# 516  adversarial-machine-learning, ai-security, art...
#
#                                            description created_at  \
# 0        🦜🔗 Build context-aware reasoning applications 2022-10-17
# 1    A cross-platform ChatGPT/Gemini UI (Web / PWA ... 2023-03-10
# 2    A curated list of awesome Machine Learning fra... 2014-07-15
# 3    A curated list of awesome C++ (or C) framework... 2014-07-17
# 4                               LLM inference in C/C++ 2023-03-10
# ..                                                 ...        ...
# 512  A curated list of NLP resources focused on Tra... 2019-01-13
# 513  LLMs interview notes and answers:该仓库主要记录大模型（LL... 2023-09-21
# 514  Codes for "Chameleon: Plug-and-Play Compositio... 2023-04-19
# 515  A highly opinionated, fully featured Obsidian ... 2022-12-08
# 516  A curated list of useful resources that cover ... 2023-01-28
#
#      stargazers_count  forks_count  \
# 0               81425        12434
# 1               66548        54259
# 2               63304        14447
# 3               55101         7613
# 4               54581         7703
# ..                ...          ...
# 512              1022          122
# 513              1019          161
# 514              1009           84
# 515              1009           49
# 516              1002           98
#
#                                                license  days_since_created  \
# 0                                          MIT License                 540
# 1                                          MIT License                 396
# 2                                                Other                3556
# 3                                          MIT License                3554
# 4                                          MIT License                 396
# ..                                                 ...                 ...
# 512                                        MIT License                1913
# 513                                        MIT License                 201
# 514                                 Apache License 2.0                 356
# 515                                        MIT License                 488
# 516  Creative Commons Attribution Share Alike 4.0 I...                 437
#
#      avg_forks_per_day  avg_stars_per_day    categories
# 0                 23.0              151.0  Applications
# 1                137.0              168.0  Applications
# 2                  4.0               18.0         Lists
# 3                  2.0               16.0         Lists
# 4                 19.0              138.0     Tutorials
# ..                 ...                ...           ...
# 512                0.0                1.0         Lists
# 513                1.0                5.0    Model repo
# 514                0.0                3.0    Model repo
# 515                0.0                2.0    Model repo
# 516                0.0                2.0         Lists
#
# [517 rows x 12 columns]

# %%
# Save the DataFrame as a CSV file
df_github.to_csv('data/github_final.csv', index=False)
